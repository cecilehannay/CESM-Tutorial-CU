# %% [markdown]
# # Downloading the CESM Code

# %% [markdown]
# The CESM source code is hosted in a GitHub repository. A **repository**, often shortened to **repo**, is an organized collection of project files and a record of how those files have changed over time.
#
# In this section, you will create a directory for the code, clone the CESM2.1.5 repository, and download the external components needed to run the mode
