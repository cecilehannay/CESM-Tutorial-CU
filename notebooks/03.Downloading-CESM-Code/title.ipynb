# %% [markdown]
# # Downloading the CESM Code

# %% [markdown]
# The CESM code lives on a GitHub repository.
#
# In this section, we will create a directory for the CESM code, and we will download CESM
# from GitHub.
