# %% [markdown]
# # 6.4 Exercise 4: Look at model output

# %% [markdown]
# <div class="alert alert-info">
#
# <strong>Exercise 4</strong>
#
# When Exercise 2 completes, look at the monthly history file.
#
# ```bash
# # go into the archive directory
# cd /glade/derecho/scratch/$USER/archive/b1850_hw/atm/hist
#
# # you should see a file named b1850_hw.cam.h0.0001-01.nc
# ls
#
# # look at the file contents
# ncdump -h b1850_hw.cam.h0.0001-01.nc
#
# # visualize the file contents (not from JupyterHub)
# module load ncview
# ncview b1850_hw.cam.h0.0001-01.nc
# ```
#
# </div>
#
# <div class="alert alert-warning">
# If your run didn't complete, you can look at example output in
# <code>/glade/derecho/scratch/amiller/archive/case01/atm/hist</code>.
# </div>

# %% [markdown]
# ## Example: `ncdump -h`
#
# ![ncdump -h example output](../../images/ncdump_example.png)
#
# ## Example: `ncview`
#
# ![ncview example](../../images/ncview_example.png)

# %% [markdown]
# ## More resources to look at output
#
# ![More output resources](../../images/output_resources.png)
#
# Full CESM Tutorial (output section): https://ncar.github.io/CESM-Tutorial/
