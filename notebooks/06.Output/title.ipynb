# %% [markdown]
# # 6 Output Files, Log Files and Timing Files

# %% [markdown]
# In this section we answer three common questions:
#
# - My run completed — where is my output?
# - My run crashed — where do I find info about why?
# - I need to estimate the resources for my run (length of each run and number of
#   submissions) — how?
