# %% [markdown]
# # 6.2 Exercise 3: Estimate run length and number of submissions

# %% [markdown]
# <div class="alert alert-info">
#
# <strong>Exercise 3</strong>
#
# Consider the model throughput for `b1850_hw`. What values of `STOP_OPTION`, `STOP_N` and
# `RESUBMIT` should you use to do a 30-year run, assuming you have a 12-hour maximum wallclock
# time per submission?
#
# - **Model throughput** = number of simulated model years per day.
# - **Maximum wallclock time** = maximum amount of time allowed on the computer to perform a
#   single run/submission.
#
# </div>
#
# ```bash
# # go into the case directory
# cd ~/cases/b1850_hw/
#
# # Look at the timing files. Find the model throughput
# cd ~/cases/b1850_hw/timing
#
# #   Overall Metrics:
# #       Model Throughput: XXX simulated years/day
#
# # Estimate the values of STOP_OPTION, STOP_N and RESUBMIT
# ```
#
# <div class="alert alert-warning">
# If your run didn't complete, you can look at example timing data in
# <code>/glade/u/home/tliefer/cases/case01</code>.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <details>
# <summary><font face="Times New Roman" color='blue'>Click here for the solution</font></summary><br>
#
# ```bash
# # Look at the timing files. Find the model throughput
# cd ~/cases/b1850_hw/timing
#
# #   Overall Metrics:
# #       Model Throughput: 14 simulated years/day
# ```
#
# We can (conservatively) run about 10 model years/day.
#
# The maximum wallclock time is 12 hours, so in one submission we can run about 5 years.
#
# To run 30 years total, we need 6 submissions of 5 years each — i.e., the *first* submission
# plus 5 resubmissions:
# ```
# STOP_N = 5
# STOP_OPTION = nyears
# RESUBMIT = 5
# ```
#
# </details>
# </div>
