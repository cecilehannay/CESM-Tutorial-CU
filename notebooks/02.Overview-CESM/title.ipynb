# %% [markdown]
# # Overview of CESM

# %% [markdown]
# In this section, we take a step back before diving into commands.
#
# In this section:
# - We look at why you might want to use CESM.
# - We introduce the five directories you will need to navigate between when you run CESM
#   ("the CESM maze"), and how to become a CESM expert by knowing your way around them.
