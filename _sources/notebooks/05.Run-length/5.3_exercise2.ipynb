# %% [markdown]
# # Exercise 2: Extend a run

# %% [markdown]
# <div class="alert alert-info">
#
# <strong>Exercise 2: Extend a run</strong>
#
# Restart your run `case01` and extend it for one month.
#
# You can look at the documentation about the `env_run.xml` variables `STOP_N`, `STOP_OPTION`,
# `RESUBMIT`, `CONTINUE_RUN`:
# http://www.cesm.ucar.edu/models/cesm2/settings/current/drv_input.html
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <details>
# <summary><font face="Times New Roman" color='blue'>Click here for hints</font></summary><br>
#
# From your case directory:
# ```bash
# cd ~/cases/case01
#
# ./xmlchange CONTINUE_RUN=TRUE
# ./xmlchange STOP_OPTION=nmonths,STOP_N=1
#
# ./case.submit
# ```
# </details>
# </div>
