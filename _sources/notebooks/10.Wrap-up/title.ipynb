# %% [markdown]
# # The One-Million Things We Didn't Cover in This Tutorial

# %% [markdown]
# CESM is a big, powerful model, and a short tutorial can only scratch the surface. In this
# closing section:
#
# - We point you to the full, week-long CESM Tutorial.
# - We point you to more resources for getting help going forward.
