# %% [markdown]
# # Types of Runs: Startup, Branch and Hybrid

# %% [markdown]
# In this section, we look at the different ways a CESM run can be initialized: **startup**,
# **branch**, and **hybrid**.
