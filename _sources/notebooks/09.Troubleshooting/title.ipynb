# %% [markdown]
# # Troubleshooting and Log Files

# %% [markdown]
# Things go wrong sometimes — a run crashes, the batch system doesn't recognize your project,
# or a case just won't build. This section collects the most common issues and where to look
# for clues.
