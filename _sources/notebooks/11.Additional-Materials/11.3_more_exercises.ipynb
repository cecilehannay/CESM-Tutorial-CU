# %% [markdown]
# # More resources: additional namelist / SourceMods exercises

# %% [markdown]
# These optional "challenge" exercises go beyond what we can cover live in this tutorial, but
# are great practice. They are hosted on the full CESM Tutorial website:
#
# - **Output high-frequency data in CAM** —
#   https://ncar.github.io/CESM-Tutorial/notebooks/namelist/exercises_overview.html
# - **Change a tuning parameter in CAM** —
#   https://ncar.github.io/CESM-Tutorial/notebooks/namelist/exercises_overview.html

# %% [markdown]
# ![Namelist challenge exercise diagram](../../images/exercise_output_diagram_1.png)
# ![Namelist challenge exercise diagram](../../images/exercise_output_diagram_2.png)

# %% [markdown]
# ## Increase orographic height over the western US
#
# https://ncar.github.io/CESM-Tutorial/notebooks/challenge/cam/exercise_4.html
#
# This exercise uses `SourceMods` / boundary-condition file edits rather than a simple
# namelist change — a good next step once you're comfortable with `user_nl_*` files.

# %% [markdown]
# ## Increase prescribed SST by 2K in the tropical central Pacific
#
# https://ncar.github.io/CESM-Tutorial/notebooks/challenge/cam/exercise_5.html
#
# ![Prescribed SST perturbation region](../../images/exercise_prescribed_sst.png)
#
# More resources: full CESM Tutorial — https://ncar.github.io/CESM-Tutorial/
